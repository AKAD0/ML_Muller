# %% [markdown]
# # Chapter 5. Model evaluation and enhancement.
# # Part 1. Cross-validation.
# Better method to evaluate model's accuracy.

# %% [markdown]
# ## - Cross-validation implementation
# 'cross_val_score' - the function to perform cross-validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

iris = load_iris()
logreg = LogisticRegression()

#'cv' sets the number of folds in cross-validation
scores = cross_val_score(logreg, iris.data, iris.target, cv=6)
print('Cross-validation results: {}'.format(scores))

#taking a mean of scores
print('Scores mean: {}'.format(scores.mean()))
# Out:
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# It's important to remember that cross-validation is designed only to check generalizing ability

# %% [markdown]
# ## - Cross-validation adjustment

# %% [markdown]
# #### 1) 'KFold'
# Instead of number for 'cv' param there could be used 'KFold' to define specific way to fold data

# %%
from sklearn.model_selection import KFold

#'shuffle' randomly shuffles dataset (instead of stratification)
kfold = KFold(n_splits=5, shuffle=True, random_state=0)
print('Cross validation accuracy: {}'.format(cross_val_score(logreg, iris.data, iris.target, cv=kfold)))
# Out:
# Cross validation accuracy: [1.         0.83333333 1.         1.         0.93333333]
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# #### 2) 'Leave-one-out'
# The method in which every fold is a sample itself. Method demands a lot of time to complete but gives more accurate evaluations.

# %%
from sklearn.model_selection import LeaveOneOut

loo = LeaveOneOut()
scores = cross_val_score(logreg, iris.data, iris.target, cv=loo)
print('Iterations count: {}'.format(len(scores)))
print('Mean accuracy: {}'.format(scores.mean()))
# Out:
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# #### 3) 'Shuffle-split cross-validation'
# Method takes given number of random train and test samples out of whole dataset and validates iteratively given number of times.

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedShuffleSplit

shuffle_split = ShuffleSplit(test_size=0.5, train_size=0.5, n_splits=10)
strat_shuffle_split = StratifiedShuffleSplit(test_size=0.5, train_size=0.5, n_splits=10)

scores = cross_val_score(logreg, iris.data, iris.target, cv=shuffle_split)
strat_scores = cross_val_score(logreg, iris.data, iris.target, cv=strat_shuffle_split)

print('Cross validation accuracy: {}'.format(scores))
print('Stratified cross validation accuracy: {}'.format(strat_scores))
# Out:
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/akado/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# #### 4) 'GroupKFold'
# Method keeps samples in groups as cross-validation separates dataset to train and test sets.

# %%
from sklearn.model_selection import GroupKFold
from sklearn.datasets import make_blobs

#generating dataset
X,y = make_blobs(n_samples=12, random_state=0)

#grouping data by giving group indexes for each sample via...
#...array of indexes
groups = [0,0,0,1,1,1,1,2,2,3,3,3]

scores = cross_val_score(logreg, X,y, groups, cv=GroupKFold(n_splits=3))
print('Cross-validation accuracy: {}'.format(scores))
# Out:
# Cross-validation accuracy: [0.75       0.6        0.66666667]
# /home/akado/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass groups=[0, 0, 0, 1, 1, 1, 1, 2, 2, 3, 3, 3] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
